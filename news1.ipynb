# %%
# !git clone https://github.com/SawanGurjar/news_crawler.git
# Out:
# Cloning into 'news_crawler'...
# remote: Enumerating objects: 6, done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 6
# Unpacking objects: 100% (6/6), done.

# %%
# !pwd https://github.com/SawanGurjar/news_crawler.git
# Out:
# /content/news_crawler

# %%
cd news_crawler
# Out:
# /content/news_crawler/news_crawler

# %%
# !python3 'news_crawler_application.ipynb'

# %%
# !pip install NewsApi-python
# Out:
# Requirement already satisfied: NewsApi-python in /usr/local/lib/python3.6/dist-packages (0.2.6)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from NewsApi-python) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->NewsApi-python) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->NewsApi-python) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->NewsApi-python) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->NewsApi-python) (3.0.4)

# %%
#importing libraries

from ipywidgets import widgets
from ipywidgets import *
from traitlets import *
from IPython.display import display, Markdown

#converting unicode to string
import unicodedata

#NewsApiClient to find URLs of news
from newsapi import NewsApiClient

# Requests is used to get a html markup from a URL
import requests

# Beautiful Soup for crawling and capturing text
from bs4 import BeautifulSoup

# %%
newsapi = NewsApiClient(api_key='27a062ac4e3340bead02d732875bddff')

all_articles = newsapi.get_everything(q = 'modi',
                                      language='en',
                                      sources='cnn',
                                      sort_by = 'relevancy',
                                      page_size = 10)
#display(all_articles)

# %%
list_url = []
for item in all_articles['articles']:
    list_url.append(unicodedata.normalize('NFKD', item['url']).encode('ascii','ignore'))
display(list_url)
# Out:
# [b'https://www.cnn.com/2020/08/14/world/meanwhile-in-america-august-13-intl/index.html',
#  b'https://www.cnn.com/2020/07/26/asia/india-coronavirus-narendra-modi-intl/index.html',
#  b'https://www.cnn.com/2020/08/01/india/amar-singh-death-intl/index.html',
#  b'https://www.cnn.com/2020/08/04/asia/ayodhya-temple-modi-foundation-stone-intl-hnk/index.html',
#  b'https://www.cnn.com/2020/08/15/opinions/what-kamala-harris-means-to-indian-americans-singh/index.html',
#  b'https://www.cnn.com/2020/08/07/asia/india-coronavirus-two-million-intl-hnk/index.html',
#  b'https://www.cnn.com/2020/08/17/entertainment/pandit-jasraj-death-india-trnd/index.html',
#  b'https://www.cnn.com/2020/08/03/opinions/kamala-harris-asian-americans-vp-pick-biden-makhija/index.html',
#  b'https://www.cnn.com/2020/08/07/asia/sri-lanka-election-mahinda-rajapaksa-intl-hnk/index.html',
#  b'https://www.cnn.com/2020/08/12/asia/environmentalist-india-lakes-c2e-scn-spc-intl/index.html']

# %%
article_content = []
for i in list_url:
    page = requests.get(i)
    soup = BeautifulSoup(page.content, 'html.parser')
    content = soup.find_all(['p'])
    for line in content:
        line_string = unicodedata.normalize('NFKD', line.get_text()).encode('ascii','ignore')
        if (len(line_string)>20):
            article_content.append(line_string)
    article_content.append(',')

# %%
counter = 1
display(Markdown("# Article " + str(counter)))
for line in article_content:
    if(line == ','):
        counter = counter + 1
        if (not(counter<=10)):
            break;
        display(Markdown("# Article " + str(counter)))
        continue
    display(line)
# Out:
# # Article 1
# b'Analysis by Stephen Collinson with Caitlin Hu, CNN'
# b'Updated 7:37 AM ET, Sat August 15, 2020 '
# b"Chat with us in Facebook Messenger. Find out what's happening in the world as it unfolds."
# b"This was excerpted from the August 13 edition of CNN's Meanwhile in America, the daily email about US politics for global readers. Click here to read past editions and subscribe."
# b' (CNN)These are serious times.'
# # Article 2
# b'By Rishabh M. Pratap and Zamira Rahim'
# b'Updated 2:49 PM ET, Sun July 26, 2020 '
# b"Chat with us in Facebook Messenger. Find out what's happening in the world as it unfolds."
# b" (CNN)Indian Prime Minister Narendra Modi has claimed that his country's response to the pandemic has defied global expectations."
# # Article 3
# b'Updated 11:45 AM ET, Sat August 1, 2020 '
# b"Chat with us in Facebook Messenger. Find out what's happening in the world as it unfolds."
#